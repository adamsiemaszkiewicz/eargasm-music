# %% [markdown]
# #### Install and import essential libraries

# %%
pip install spotipy --upgrade
# Out:
# Requirement already up-to-date: spotipy in c:\users\adam\miniconda3\envs\ml\lib\site-packages (2.16.0)
# Requirement already satisfied, skipping upgrade: requests>=2.20.0 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from spotipy) (2.24.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from requests>=2.20.0->spotipy) (1.25.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\adam\miniconda3\envs\ml\lib\site-packages (from requests>=2.20.0->spotipy) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\adam\miniconda3\envs\ml\lib\site-packages (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import OS functionality & load environment variables from the local `.env`

# %%
import os
from dotenv import load_dotenv
load_dotenv()

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

# %% [markdown]
# #### Import spotipy library to use Spotify Web API
# https://spotipy.readthedocs.io/

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,
                                                      client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
USER = 'eargasmusic'
user = sp.user(USER)
user
# Out:
# {'display_name': 'Eargasm Musicblog',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#  'followers': {'href': None, 'total': 321},
#  'href': 'https://api.spotify.com/v1/users/eargasmusic',
#  'id': 'eargasmusic',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab6775700000ee85c34f83b0dc82b7ff64a06ac5',
#    'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:eargasmusic'}

# %%
playlists = sp.user_playlists(USER)
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/eargasmusic/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5apHWYcigR3lSZpyzyGKEa'},
#    'href': 'https://api.spotify.com/v1/playlists/5apHWYcigR3lSZpyzyGKEa',
#    'id': '5apHWYcigR3lSZpyzyGKEa',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbd3ccf5f082f33edea4a71b93',
#      'width': None}],
#    'name': 'eargasm | breathe easy',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDQyLGNlNTRkNzg1YTI1YWZhN2E3N2Y5MDBjNWU3MjJkN2MxYTMyZjYyOTU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5apHWYcigR3lSZpyzyGKEa/tracks',
#     'total': 173},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5apHWYcigR3lSZpyzyGKEa'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3MXM4ca1b3bT198F7mG9ms'},
#    'href': 'https://api.spotify.com/v1/playlists/3MXM4ca1b3bT198F7mG9ms',
#    'id': '3MXM4ca1b3bT198F7mG9ms',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84e10d9c77a8bbb2a34193da48',
#      'width': 300}],
#    'name': 'eargasm | city walk',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDY0LGZhMDUyMjQ2ZjFhODBhZjYwZGYwY2Q1NWEzM2EwNjBiNDc5YmVmNjc=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3MXM4ca1b3bT198F7mG9ms/tracks',
#     'total': 242},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3MXM4ca1b3bT198F7mG9ms'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2QdM3NBe7lkOzC7OqWXfNI'},
#    'href': 'https://api.spotify.com/v1/playlists/2QdM3NBe7lkOzC7OqWXfNI',
#    'id': '2QdM3NBe7lkOzC7OqWXfNI',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb2aa3904af7e13577641e188c',
#      'width': None}],
#    'name': 'eargasm | curvatronik',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDk3LGI2NjYxZTkzMzFmZmRkZmFjNzczODhmZjdjNjRhYjBmZTMwNmJkNWU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2QdM3NBe7lkOzC7OqWXfNI/tracks',
#     'total': 213},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2QdM3NBe7lkOzC7OqWXfNI'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1CwPTyGbQDSda6m7vTys1d'},
#    'href': 'https://api.spotify.com/v1/playlists/1CwPTyGbQDSda6m7vTys1d',
#    'id': '1CwPTyGbQDSda6m7vTys1d',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84c70dd4edb44d52aad9d7ec14',
#      'width': 300}],
#    'name': 'eargasm | decadency',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTI5LGQ2Zjc3ZGY5ZDkxNTc5ZTgwZTJmNTU4NDU3OTlmMDZiYWQzYWMyZDI=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1CwPTyGbQDSda6m7vTys1d/tracks',
#     'total': 68},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1CwPTyGbQDSda6m7vTys1d'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6pGQQZ4PITmFnSC0rTnmXp'},
#    'href': 'https://api.spotify.com/v1/playlists/6pGQQZ4PITmFnSC0rTnmXp',
#    'id': '6pGQQZ4PITmFnSC0rTnmXp',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da846e34ffcfa7ca202302f8891c',
#      'width': 300}],
#    'name': 'eargasm | deep water',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTQ4LGJmYTdhMmNlOTVmMTdiZWRlZWI3NjRmNmJiMDA3NWQ1ZmVmODAwYjk=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6pGQQZ4PITmFnSC0rTnmXp/tracks',
#     'total': 93},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6pGQQZ4PITmFnSC0rTnmXp'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7tOxW8H2qzxGmIgwAFSYrw'},
#    'href': 'https://api.spotify.com/v1/playlists/7tOxW8H2qzxGmIgwAFSYrw',
#    'id': '7tOxW8H2qzxGmIgwAFSYrw',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8446f0c1b455b45f19f271e504',
#      'width': 300}],
#    'name': 'eargasm | departure',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjUxLDI5OThhMWY1NWU4YTcxMGI3ZjRkYzVlOTY5MmM0ZWFhMWIzOWM2ZmU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7tOxW8H2qzxGmIgwAFSYrw/tracks',
#     'total': 112},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7tOxW8H2qzxGmIgwAFSYrw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1YfxkylLN0ecX19mAquHGy'},
#    'href': 'https://api.spotify.com/v1/playlists/1YfxkylLN0ecX19mAquHGy',
#    'id': '1YfxkylLN0ecX19mAquHGy',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb5df4b8f9ae2b004c46504778',
#      'width': None}],
#    'name': 'eargasm | dust settling',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'OTUsMjQxMTczZDZhNWMwMzUyMGJiYTQyMjM4OWQ4ZTRkZmQ4MWZmNzllNQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1YfxkylLN0ecX19mAquHGy/tracks',
#     'total': 85},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1YfxkylLN0ecX19mAquHGy'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1zPa9pKaSsIZYVuuxZqAdv'},
#    'href': 'https://api.spotify.com/v1/playlists/1zPa9pKaSsIZYVuuxZqAdv',
#    'id': '1zPa9pKaSsIZYVuuxZqAdv',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8435be3bb6334f34daea56b371',
#      'width': 300}],
#    'name': 'eargasm | get moving',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTg1LDZmN2MxMmNjZGRlODg5NzMyYWUzNTRkNWIyMjRjODc0NWM5MjM3MGE=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1zPa9pKaSsIZYVuuxZqAdv/tracks',
#     'total': 125},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1zPa9pKaSsIZYVuuxZqAdv'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4aVYl96G4Xjfsc7IT1V8pj'},
#    'href': 'https://api.spotify.com/v1/playlists/4aVYl96G4Xjfsc7IT1V8pj',
#    'id': '4aVYl96G4Xjfsc7IT1V8pj',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da842a3f8d7419ba54494fd9a5a8',
#      'width': 300}],
#    'name': 'eargasm | glide',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Mjg1LDY3NmI0ZTQxYTIxNDVmZjkxOGE4ZDIzZWJiYjIwNWRmYzQ5MjliN2I=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4aVYl96G4Xjfsc7IT1V8pj/tracks',
#     'total': 83},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4aVYl96G4Xjfsc7IT1V8pj'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5s9oeBauiz5PDbDHCRix0Y'},
#    'href': 'https://api.spotify.com/v1/playlists/5s9oeBauiz5PDbDHCRix0Y',
#    'id': '5s9oeBauiz5PDbDHCRix0Y',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbc42e08933e5df914f0c2317c',
#      'width': None}],
#    'name': 'eargasm | high frequency radio',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTIxLGZkMTYxY2E5ZDFlYWYxNDNjYjA3ZjdkOTAxODQ2NTMzYWViMzc4ZTc=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5s9oeBauiz5PDbDHCRix0Y/tracks',
#     'total': 170},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5s9oeBauiz5PDbDHCRix0Y'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7nrsN5xIdh0ol5cOV3Ri5D'},
#    'href': 'https://api.spotify.com/v1/playlists/7nrsN5xIdh0ol5cOV3Ri5D',
#    'id': '7nrsN5xIdh0ol5cOV3Ri5D',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da845f9ad2caef14c14d0c0bc255',
#      'width': 300}],
#    'name': 'eargasm | into the wild',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzI4LDk1Y2FlMzFmNTM3NjIzNGE5N2RhNTZmZmI3NmMyYzY0YjhiYjg2MWE=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7nrsN5xIdh0ol5cOV3Ri5D/tracks',
#     'total': 75},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7nrsN5xIdh0ol5cOV3Ri5D'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5gMjf6A0YH9rALweR0ejeO'},
#    'href': 'https://api.spotify.com/v1/playlists/5gMjf6A0YH9rALweR0ejeO',
#    'id': '5gMjf6A0YH9rALweR0ejeO',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84767bc977ee8ba5f749476e4c',
#      'width': 300}],
#    'name': 'eargasm | joyride',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzIxLDY0NGFiOTUwNWZmZjU1NTQwMmM4YzU1NzAzN2UwMDRkMzJiYjIwNjY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5gMjf6A0YH9rALweR0ejeO/tracks',
#     'total': 167},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5gMjf6A0YH9rALweR0ejeO'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/35W6kXZzWwRBcmHvKDRvyE'},
#    'href': 'https://api.spotify.com/v1/playlists/35W6kXZzWwRBcmHvKDRvyE',
#    'id': '35W6kXZzWwRBcmHvKDRvyE',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8422c999d59433703c6709e40b',
#      'width': 300}],
#    'name': "eargasm | kickin' it ol' skool",
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTk2LDIyOTc4MjVmYjI2YzJhODU5ZjEzZWExZTAwNmQ2ZTc3NDM0YmY1NTY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/35W6kXZzWwRBcmHvKDRvyE/tracks',
#     'total': 94},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:35W6kXZzWwRBcmHvKDRvyE'},
#   {'collaborative': False,
#    'description': 'music to hang out to',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7a87R9rSGECEIJgDeVrojF'},
#    'href': 'https://api.spotify.com/v1/playlists/7a87R9rSGECEIJgDeVrojF',
#    'id': '7a87R9rSGECEIJgDeVrojF',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb10a80cc158fb8d8a05d83d69',
#      'width': None}],
#    'name': "eargasm | loungin'",
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzY4LDcwNThkMzJmZGFiODQ2NTE3MDNhYmI3ZGIwMzM3MjM5OGE2OTEzMTU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7a87R9rSGECEIJgDeVrojF/tracks',
#     'total': 133},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7a87R9rSGECEIJgDeVrojF'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/31KDCs5aYq9okxLnsdgOIH'},
#    'href': 'https://api.spotify.com/v1/playlists/31KDCs5aYq9okxLnsdgOIH',
#    'id': '31KDCs5aYq9okxLnsdgOIH',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8471e838324564fc4f31b89cc7',
#      'width': 300}],
#    'name': 'eargasm | neon socks',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzkyLDNiM2NiZTNiY2JlMDFlNTc1OTM2MGE0MGRjMjM1NDFjZGMyMjU1NTQ=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/31KDCs5aYq9okxLnsdgOIH/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:31KDCs5aYq9okxLnsdgOIH'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5LzidLwoF4Th3WDHUoUEOK'},
#    'href': 'https://api.spotify.com/v1/playlists/5LzidLwoF4Th3WDHUoUEOK',
#    'id': '5LzidLwoF4Th3WDHUoUEOK',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84eadef544470c81128e1a744b',
#      'width': 300}],
#    'name': 'eargasm | on top',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'ODAsNDRmOTA0MjQxMmJjYTMwNDlkMmQwMDI0ZjZjYWVkMWExNDdlNmY5NA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5LzidLwoF4Th3WDHUoUEOK/tracks',
#     'total': 39},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5LzidLwoF4Th3WDHUoUEOK'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3MmEnUrCupZobijAHTeHLE'},
#    'href': 'https://api.spotify.com/v1/playlists/3MmEnUrCupZobijAHTeHLE',
#    'id': '3MmEnUrCupZobijAHTeHLE',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da849c6a244f4e35b036f9c4dec3',
#      'width': 300}],
#    'name': 'eargasm | organised noise',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Mzk3LGE4NzA2MWZiY2ExYjNjYzQwZGFmMzA2MTExNmYyNWRiY2Q4Zjc1NTY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3MmEnUrCupZobijAHTeHLE/tracks',
#     'total': 163},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3MmEnUrCupZobijAHTeHLE'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/190gSyrWHdtxGe8cHbx1vr'},
#    'href': 'https://api.spotify.com/v1/playlists/190gSyrWHdtxGe8cHbx1vr',
#    'id': '190gSyrWHdtxGe8cHbx1vr',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb8fedcf15d581717a28a2e35b',
#      'width': None}],
#    'name': 'eargasm | oscilloscope',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjIyLGM0YjJhZDY4NDQ0NzY2OTdiZWQ5ZDUyMjk2OTA3MTg2NmU3NDg0YmE=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/190gSyrWHdtxGe8cHbx1vr/tracks',
#     'total': 131},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:190gSyrWHdtxGe8cHbx1vr'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/27kF0yvqV2v4NUkfqBJA11'},
#    'href': 'https://api.spotify.com/v1/playlists/27kF0yvqV2v4NUkfqBJA11',
#    'id': '27kF0yvqV2v4NUkfqBJA11',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da846aad3276fee1ac225c0eed2d',
#      'width': 300}],
#    'name': 'eargasm | polymers',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NjE2LDA0ODY5MTI4NDAzZjc2ZmNjYWE5M2MzZWZmYWEwY2Y0Njk1N2JmNGY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/27kF0yvqV2v4NUkfqBJA11/tracks',
#     'total': 281},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:27kF0yvqV2v4NUkfqBJA11'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7FJAYsYTBwsGqXxSwl5Jht'},
#    'href': 'https://api.spotify.com/v1/playlists/7FJAYsYTBwsGqXxSwl5Jht',
#    'id': '7FJAYsYTBwsGqXxSwl5Jht',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84efe054160a8c3a7b1c87d490',
#      'width': 300}],
#    'name': 'eargasm | ptsd',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTMxLGU0NGRjZTE5MGM1YWUyNTFhYzgzNTVmNWIyYzA1OTAyM2M2YTkyNmM=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7FJAYsYTBwsGqXxSwl5Jht/tracks',
#     'total': 123},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7FJAYsYTBwsGqXxSwl5Jht'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/53N2EgQ15C9MxejBqbMRLr'},
#    'href': 'https://api.spotify.com/v1/playlists/53N2EgQ15C9MxejBqbMRLr',
#    'id': '53N2EgQ15C9MxejBqbMRLr',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84597cc4004c34ff6402ca70fb',
#      'width': 300}],
#    'name': 'eargasm | sky gazing',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTI1LDEwMjcwYTQwODI0YWVhNzEwNzg4ZWY4ZjExOTRiMmFkOGQ1ZDA4Mjk=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/53N2EgQ15C9MxejBqbMRLr/tracks',
#     'total': 44},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:53N2EgQ15C9MxejBqbMRLr'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7Ij6BX3PvfwgItYiXVXaU3'},
#    'href': 'https://api.spotify.com/v1/playlists/7Ij6BX3PvfwgItYiXVXaU3',
#    'id': '7Ij6BX3PvfwgItYiXVXaU3',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb4af697cfb30555025d569394',
#      'width': None}],
#    'name': 'eargasm | sleepwalking',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjY2LDA0ZmZiODc3YTg0ODA4Mjk4MGYwMjlhNzQ0MGE2ZWZkYWI2OWU1YjA=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7Ij6BX3PvfwgItYiXVXaU3/tracks',
#     'total': 130},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7Ij6BX3PvfwgItYiXVXaU3'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/21gcPcBIyOJ94ZQRCblo0w'},
#    'href': 'https://api.spotify.com/v1/playlists/21gcPcBIyOJ94ZQRCblo0w',
#    'id': '21gcPcBIyOJ94ZQRCblo0w',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da843d021878d311d584e68436c9',
#      'width': 300}],
#    'name': 'eargasm | solitary confinement',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDYyLDU4MzFlMTM1YmNlZDE0NTliZDc2YTEyNjI1ZWY2ZDkxMzU5MTQxZmQ=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/21gcPcBIyOJ94ZQRCblo0w/tracks',
#     'total': 131},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:21gcPcBIyOJ94ZQRCblo0w'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7A21vKIId6f8j2tlcPZ8tw'},
#    'href': 'https://api.spotify.com/v1/playlists/7A21vKIId6f8j2tlcPZ8tw',
#    'id': '7A21vKIId6f8j2tlcPZ8tw',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb49081ebd836a86b9f21c95a1',
#      'width': None}],
#    'name': 'eargasm | space odyssey',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzM5LDI3NGIyZWZlZmVmMzZjZWI3NTc3ZTBlMTQ4MTA5MDM1Y2NiNThlZWI=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7A21vKIId6f8j2tlcPZ8tw/tracks',
#     'total': 176},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7A21vKIId6f8j2tlcPZ8tw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2ZfWdyIxmbSf46bV1Usk9I'},
#    'href': 'https://api.spotify.com/v1/playlists/2ZfWdyIxmbSf46bV1Usk9I',
#    'id': '2ZfWdyIxmbSf46bV1Usk9I',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84020d698ba18263ae6b034f9b',
#      'width': 300}],
#    'name': 'eargasm | sunny days',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzM3LDk5NzliMTA3M2NjOWQ3OWQ2YzU3NmFlYzExOWE5YjUyYmM4MjAzYjU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2ZfWdyIxmbSf46bV1Usk9I/tracks',
#     'total': 62},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2ZfWdyIxmbSf46bV1Usk9I'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0S4uGClLWS8NK1gYaZ5Mna'},
#    'href': 'https://api.spotify.com/v1/playlists/0S4uGClLWS8NK1gYaZ5Mna',
#    'id': '0S4uGClLWS8NK1gYaZ5Mna',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8418923c70774322218dcade0c',
#      'width': 300}],
#    'name': 'eargasm | swimming pool sunset',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjMwLDVhYmU1OTY5MmNjNGI0ZjgwMzM4ZDdhYzliZmIyOTc0NmQzMTY5YzI=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0S4uGClLWS8NK1gYaZ5Mna/tracks',
#     'total': 157},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0S4uGClLWS8NK1gYaZ5Mna'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/73Thk8F2Bl6wZd0rpdrW2W'},
#    'href': 'https://api.spotify.com/v1/playlists/73Thk8F2Bl6wZd0rpdrW2W',
#    'id': '73Thk8F2Bl6wZd0rpdrW2W',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb37b69c7c13270a9bb6ebf317',
#      'width': None}],
#    'name': 'eargasm | warm up',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjU1LGVlZmU1NDMwNmI5NmUwOWEzODNmODNhMGMyZjk2ZjdkM2I4YWJkZTA=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/73Thk8F2Bl6wZd0rpdrW2W/tracks',
#     'total': 94},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:73Thk8F2Bl6wZd0rpdrW2W'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/29OXcQTp1HPeniNeVulnq4'},
#    'href': 'https://api.spotify.com/v1/playlists/29OXcQTp1HPeniNeVulnq4',
#    'id': '29OXcQTp1HPeniNeVulnq4',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8436b72774423031d7df48c2ce',
#      'width': 300}],
#    'name': 'eargasm | we up all night',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTEwLGIwNmY3ZTY0ZWNjMWRkYTgxMjQwYTkxZGU4NzU1YmIwZmNhMGZhNzY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/29OXcQTp1HPeniNeVulnq4/tracks',
#     'total': 34},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:29OXcQTp1HPeniNeVulnq4'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/39Vs61fBBQr7CArKL5iLTT'},
#    'href': 'https://api.spotify.com/v1/playlists/39Vs61fBBQr7CArKL5iLTT',
#    'id': '39Vs61fBBQr7CArKL5iLTT',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb64818e997557bb982034de9c',
#      'width': None}],
#    'name': 'eargasm | weightless',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTA1LDY2ZWQ4ZTgxZTBhZjQwMzllYTY0N2UxOTEyMTJmZDIyOTg0ZjU0NDk=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/39Vs61fBBQr7CArKL5iLTT/tracks',
#     'total': 123},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:39Vs61fBBQr7CArKL5iLTT'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/43754bIdP7b0ygh8tTMenW'},
#    'href': 'https://api.spotify.com/v1/playlists/43754bIdP7b0ygh8tTMenW',
#    'id': '43754bIdP7b0ygh8tTMenW',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84c881c944ded8d28c9a144b75',
#      'width': 300}],
#    'name': 'eargasm music 2020',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjMsNTdmY2UxZDdlYWQ2NWI2MWQyYTE5NzVjYzBmMWEyZGY0ZGU3NTBhYg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/43754bIdP7b0ygh8tTMenW/tracks',
#     'total': 254},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:43754bIdP7b0ygh8tTMenW'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0MsxZLGhAKJyBMXAfD03db'},
#    'href': 'https://api.spotify.com/v1/playlists/0MsxZLGhAKJyBMXAfD03db',
#    'id': '0MsxZLGhAKJyBMXAfD03db',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84eabc26893e3ee462b550e45c',
#      'width': 300}],
#    'name': 'eargasm music 2019',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTIsMGI5ZDUzYzhjMWUzMjRiYWY1NDI1NTE2NmI1YWRkYWMyNDkyZmE0Yg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0MsxZLGhAKJyBMXAfD03db/tracks',
#     'total': 815},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0MsxZLGhAKJyBMXAfD03db'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4tFrGBRcTYsrz5BwCGZS8L'},
#    'href': 'https://api.spotify.com/v1/playlists/4tFrGBRcTYsrz5BwCGZS8L',
#    'id': '4tFrGBRcTYsrz5BwCGZS8L',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb96c0b2d13ef353fab0dff780',
#      'width': None}],
#    'name': 'eargasm music 2018',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTgwLDMzNDVmYTBjYTQzOTFiYWVhMDI2YzE0NjkwMDcwM2Y2MDRkZTA5N2E=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4tFrGBRcTYsrz5BwCGZS8L/tracks',
#     'total': 826},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4tFrGBRcTYsrz5BwCGZS8L'},
#   {'collaborative': False,
#    'description': 'www.EARGASMusic.com',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0tNl58CSFwviwg7LxWzdwy'},
#    'href': 'https://api.spotify.com/v1/playlists/0tNl58CSFwviwg7LxWzdwy',
#    'id': '0tNl58CSFwviwg7LxWzdwy',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84b7c8212041509b73d1a2fca2',
#      'width': 300}],
#    'name': 'eargasm music 2017',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTQyLGNlMGExZjgwMGMzODNkMWY3NTVlZjYxMTZmMTUyZThmNTMwZjVlY2E=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0tNl58CSFwviwg7LxWzdwy/tracks',
#     'total': 876},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0tNl58CSFwviwg7LxWzdwy'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2CDNi9K1M0ilAUQn1FTVp4'},
#    'href': 'https://api.spotify.com/v1/playlists/2CDNi9K1M0ilAUQn1FTVp4',
#    'id': '2CDNi9K1M0ilAUQn1FTVp4',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbde60359c791a50080086e7e5',
#      'width': None}],
#    'name': 'eargasm music 2016',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTAsYWE1NmQ1YjdmNDYyMTU0YzczMDNmZDk5NTg3ZWEzYzAyMThhNjhjMQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2CDNi9K1M0ilAUQn1FTVp4/tracks',
#     'total': 61},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2CDNi9K1M0ilAUQn1FTVp4'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4DyXuBus6lNF6rBYqcOEp5'},
#    'href': 'https://api.spotify.com/v1/playlists/4DyXuBus6lNF6rBYqcOEp5',
#    'id': '4DyXuBus6lNF6rBYqcOEp5',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84de4663faed19ef4837543df0',
#      'width': 300}],
#    'name': 'eargasm music 2015',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTUsMzY5YzJjYTI3YjZiYzBjMDEwMjI5ODU3MWY0ODU5YjI3YTdjNDRkMQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4DyXuBus6lNF6rBYqcOEp5/tracks',
#     'total': 427},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4DyXuBus6lNF6rBYqcOEp5'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Osh14RctOzyHy5JBUzqgz'},
#    'href': 'https://api.spotify.com/v1/playlists/0Osh14RctOzyHy5JBUzqgz',
#    'id': '0Osh14RctOzyHy5JBUzqgz',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbaefea629da7c4f7fd42991ee',
#      'width': None}],
#    'name': 'eargasm music 2014',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTQsNDM4ZTE0YTYyMTkwZjNlY2MzZDJiZGRiYWI3ZmNjZTI5NDUxYTBiMw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0Osh14RctOzyHy5JBUzqgz/tracks',
#     'total': 637},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0Osh14RctOzyHy5JBUzqgz'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4W6Pr8z2TWN1Ul6BtLvgCw'},
#    'href': 'https://api.spotify.com/v1/playlists/4W6Pr8z2TWN1Ul6BtLvgCw',
#    'id': '4W6Pr8z2TWN1Ul6BtLvgCw',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da8432c694c710465e5b3e4fc5de',
#      'width': 300}],
#    'name': 'eargasm music 2013',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTQsMDY0OWM0NWE0ZDBhYWU3NzgxOTJlNjQ3N2Q0NDQ1MDM2ODJmZmFiNA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4W6Pr8z2TWN1Ul6BtLvgCw/tracks',
#     'total': 744},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4W6Pr8z2TWN1Ul6BtLvgCw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3AnuCisFiGCRI0hcDQNxli'},
#    'href': 'https://api.spotify.com/v1/playlists/3AnuCisFiGCRI0hcDQNxli',
#    'id': '3AnuCisFiGCRI0hcDQNxli',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da842293044d4f377989acb7d722',
#      'width': 300}],
#    'name': 'eargasm music 2012',
#    'owner': {'display_name': 'Eargasm Musicblog',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eargasmusic'},
#     'href': 'https://api.spotify.com/v1/users/eargasmusic',
#     'id': 'eargasmusic',
#     'type': 'user',
#     'uri': 'spotify:user:eargasmusic'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'ODkzLDdjNTFhOGQzMjc5NjJhNjIwMjQxMjVkNjlhMDY3MjgzZmUyNWIxODQ=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3AnuCisFiGCRI0hcDQNxli/tracks',
#     'total': 754},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3AnuCisFiGCRI0hcDQNxli'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 38}
